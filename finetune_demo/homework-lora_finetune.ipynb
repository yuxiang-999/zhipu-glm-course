# %% [markdown]
# # 单卡GPU 进行 ChatGLM3-6B模型 LORA 高效微调
# 本 Cookbook 将带领开发者使用 `AdvertiseGen` 对 ChatGLM3-6B 数据集进行 lora微调，使其具备专业的广告生成能力。
#
# ## 硬件需求
# 显存：24GB
# 显卡架构：安培架构（推荐）
# 内存：16GB

# %% [markdown]
# ## 1. 准备数据集
# 我们使用 AdvertiseGen 数据集来进行微调。从 [Google Drive](https://drive.google.com/file/d/13_vf0xRTQsyneRKdD1bZIr93vBGOczrk/view?usp=sharing) 或者 [Tsinghua Cloud](https://cloud.tsinghua.edu.cn/f/b3f119a008264b1cabd1/?dl=1) 下载处理好的 AdvertiseGen 数据集，将解压后的 AdvertiseGen 目录放到本目录的 `/data/` 下, 例如。
# > /media/zr/Data/Code/ChatGLM3/finetune_demo/data/AdvertiseGen
#
# 接着，运行本代码来切割数据集

# %%
import json
from typing import Union
from pathlib import Path


def _resolve_path(path: Union[str, Path]) -> Path:
    return Path(path).expanduser().resolve()


def _mkdir(dir_name: Union[str, Path]):
    dir_name = _resolve_path(dir_name)
    if not dir_name.is_dir():
        dir_name.mkdir(parents=True, exist_ok=False)


def convert_adgen(data_dir: Union[str, Path], save_dir: Union[str, Path]):
    def _convert(in_file: Path, out_file: Path):
        _mkdir(out_file.parent)
        with open(in_file, encoding='utf-8') as fin:
            with open(out_file, 'wt', encoding='utf-8') as fout:
                for line in fin:
                    dct = json.loads(line)
                    sample = {'conversations': [{'role': 'user', 'content': dct['content']},
                                                {'role': 'assistant', 'content': dct['summary']}]}
                    fout.write(json.dumps(sample, ensure_ascii=False) + '\n')

    data_dir = _resolve_path(data_dir)
    save_dir = _resolve_path(save_dir)

    train_file = data_dir / 'train.json'
    if train_file.is_file():
        out_file = save_dir / train_file.relative_to(data_dir)
        _convert(train_file, out_file)

    dev_file = data_dir / 'dev.json'
    if dev_file.is_file():
        out_file = save_dir / dev_file.relative_to(data_dir)
        _convert(dev_file, out_file)


convert_adgen('data/AdvertiseGen', 'data/AdvertiseGen_fix')

# %% [markdown]
# ## 2. 使用命令行开始微调,我们使用 lora 进行微调
# 接着，我们仅需要将配置好的参数以命令行的形式传参给程序，就可以使用命令行进行高效微调，这里将 `/media/zr/Data/Code/ChatGLM3/venv/bin/python3` 换成你的 python3 的绝对路径以保证正常运行。

# %%
# !cat configs/lora.yaml
# Out:
# data_config:
#   train_file: train.json
#   val_file: dev.json
#   test_file: dev.json
#   num_proc: 24
# max_input_length: 128
# max_output_length: 256
# training_args:
#   # see `transformers.Seq2SeqTrainingArguments`
#   output_dir: ./output
#   max_steps: 50000
#   # settings for data loading
#   per_device_train_batch_size: 4
#   dataloader_num_workers: 24
#   remove_unused_columns: false
#   # settings for saving checkpoints
#   save_strategy: steps
#   save_steps: 5000
#   # settings for logging
#   log_level: info
#   logging_strategy: steps
#   logging_steps: 500
#   # settings for evaluation
#   per_device_eval_batch_size: 16
#   evaluation_strategy: steps
#   eval_steps: 5000
#   # settings for optimizer
#   # adam_epsilon: 1e-6
#   # uncomment the following line to detect nan or inf values
#   # debug: underflow_overflow
#   predict_with_generate: true
#   # see `transformers.GenerationConfig`
#   generation_config:
#     max_new_tokens: 256
#   # set your absolute deepspeed path here
#   #deepspeed: ds_zero_2.json
#   # set to true if train with cpu.
#   use_cpu: false
# peft_config:
#   peft_type: LORA
#   task_type: CAUSAL_LM
#   r: 16
#   lora_alpha: 64
#   lora_dropout: 0.1

# %%
# !export python_dir='/home/yuxiang/miniconda3/envs/py311_llm_dev/bin' \
&& export base_model_dir='/home/yuxiang/local/ai_workspace/.cache/huggingface/hub/models--THUDM--chatglm3-6b/snapshots/f30825950ce00cb0577bf6a15e0d95de58e328dc' \
&& export CUDA_VISIBLE_DEVICES=0 \
&& ${python_dir}/python3 finetune_hf.py  data/AdvertiseGen_fix  ${base_model_dir}  configs/lora.yaml
# Out:
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:02<00:00,  3.37it/s]
# trainable params: 3,899,392 || all params: 6,247,483,392 || trainable%: 0.06241540401681151
# --> Model
#
# --> model has 3.899392M params
#
# train_dataset: Dataset({
#     features: ['input_ids', 'labels'],
#     num_rows: 114599
# })
# val_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# test_dataset: Dataset({
#     features: ['input_ids', 'output_ids'],
#     num_rows: 1070
# })
# --> Sanity check
#            '[gMASK]': 64790 -> -100
#                'sop': 64792 -> -100
#           '<|user|>': 64795 -> -100
#                   '': 30910 -> -100
#                 '\n': 13 -> -100
#                   '': 30910 -> -100
#                 '类型': 33467 -> -100
#                  '#': 31010 -> -100
#                  '裤': 56532 -> -100
#                  '*': 30998 -> -100
#                  '版': 55090 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                 '宽松': 40833 -> -100
#                  '*': 30998 -> -100
#                 '风格': 32799 -> -100
#                  '#': 31010 -> -100
#                 '性感': 40589 -> -100
#                  '*': 30998 -> -100
#                 '图案': 37505 -> -100
#                  '#': 31010 -> -100
#                 '线条': 37216 -> -100
#                  '*': 30998 -> -100
#                  '裤': 56532 -> -100
#                  '型': 54888 -> -100
#                  '#': 31010 -> -100
#                  '阔': 56529 -> -100
#                  '腿': 56158 -> -100
#                  '裤': 56532 -> -100
#      '<|assistant|>': 64796 -> -100
#                   '': 30910 -> 30910
#                 '\n': 13 -> 13
#                   '': 30910 -> 30910
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '阔': 56529 -> 56529
#                  '腿': 56158 -> 56158
#                  '裤': 56532 -> 56532
#                  '这': 54551 -> 54551
#                 '两年': 33808 -> 33808
#                 '真的': 32041 -> 32041
#                  '吸': 55360 -> 55360
#                  '粉': 55486 -> 55486
#                 '不少': 32138 -> 32138
#                  '，': 31123 -> 31123
#                 '明星': 32943 -> 32943
#                 '时尚': 33481 -> 33481
#                  '达': 54880 -> 54880
#                 '人的': 31664 -> 31664
#                 '心头': 46565 -> 46565
#                  '爱': 54799 -> 54799
#                  '。': 31155 -> 31155
#                 '毕竟': 33051 -> 33051
#                  '好': 54591 -> 54591
#                  '穿': 55432 -> 55432
#                 '时尚': 33481 -> 33481
#                  '，': 31123 -> 31123
#                  '谁': 55622 -> 55622
#                 '都能': 32904 -> 32904
#                  '穿': 55432 -> 55432
#                  '出': 54557 -> 54557
#                  '腿': 56158 -> 56158
#                  '长': 54625 -> 54625
#                  '2': 30943 -> 30943
#                  '米': 55055 -> 55055
#                '的效果': 35590 -> 35590
#                 '宽松': 40833 -> 40833
#                  '的': 54530 -> 54530
#                  '裤': 56532 -> 56532
#                  '腿': 56158 -> 56158
#                  '，': 31123 -> 31123
#                '当然是': 48466 -> 48466
#                  '遮': 57148 -> 57148
#                  '肉': 55343 -> 55343
#                  '小': 54603 -> 54603
#                 '能手': 49355 -> 49355
#                  '啊': 55674 -> 55674
#                  '。': 31155 -> 31155
#                 '上身': 51605 -> 51605
#                  '随': 55119 -> 55119
#                  '性': 54642 -> 54642
#                 '自然': 31799 -> 31799
#                  '不': 54535 -> 54535
#                  '拘': 57036 -> 57036
#                  '束': 55625 -> 55625
#                  '，': 31123 -> 31123
#                 '面料': 46839 -> 46839
#                  '亲': 55113 -> 55113
#                  '肤': 56089 -> 56089
#                 '舒适': 33894 -> 33894
#                  '贴': 55778 -> 55778
#                 '身体': 31902 -> 31902
#                  '验': 55017 -> 55017
#                  '感': 54706 -> 54706
#                  '棒': 56382 -> 56382
#                  '棒': 56382 -> 56382
#                  '哒': 59230 -> 59230
#                  '。': 31155 -> 31155
#                  '系': 54712 -> 54712
#                  '带': 54882 -> 54882
#                 '部分': 31726 -> 31726
#                 '增加': 31917 -> 31917
#                 '设计': 31735 -> 31735
#                 '看点': 45032 -> 45032
#                  '，': 31123 -> 31123
#                  '还': 54656 -> 54656
#                  '让': 54772 -> 54772
#                 '单品': 46539 -> 46539
#                '的设计': 34481 -> 34481
#                  '感': 54706 -> 54706
#                 '更强': 43084 -> 43084
#                  '。': 31155 -> 31155
#                 '腿部': 46799 -> 46799
#                 '线条': 37216 -> 37216
#                  '若': 55351 -> 55351
#                  '隐': 55733 -> 55733
#                  '若': 55351 -> 55351
#                  '现': 54600 -> 54600
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                 '性感': 40589 -> 40589
#                  '撩': 58521 -> 58521
#                  '人': 54533 -> 54533
#                  '。': 31155 -> 31155
#                 '颜色': 33692 -> 33692
#                  '敲': 57004 -> 57004
#                 '温柔': 34678 -> 34678
#                  '的': 54530 -> 54530
#                  '，': 31123 -> 31123
#                  '与': 54619 -> 54619
#                 '裤子': 44722 -> 44722
#                 '本身': 32754 -> 32754
#                  '所': 54626 -> 54626
#                 '呈现': 33169 -> 33169
#                '的风格': 48084 -> 48084
#                 '有点': 33149 -> 33149
#                  '反': 54955 -> 54955
#                  '差': 55342 -> 55342
#                  '萌': 56842 -> 56842
#                  '。': 31155 -> 31155
#                   '': 2 -> 2
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 114,599
#   Num Epochs = 2
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 50,000
#   Number of trainable parameters = 3,899,392
# {'loss': 3.618, 'learning_rate': 4.9500000000000004e-05, 'epoch': 0.02}
# {'loss': 3.4412, 'learning_rate': 4.9e-05, 'epoch': 0.03}
# {'loss': 3.3825, 'learning_rate': 4.85e-05, 'epoch': 0.05}
# {'loss': 3.3656, 'learning_rate': 4.8e-05, 'epoch': 0.07}
# {'loss': 3.3444, 'learning_rate': 4.75e-05, 'epoch': 0.09}
# {'loss': 3.3261, 'learning_rate': 4.7e-05, 'epoch': 0.1}
# {'loss': 3.2974, 'learning_rate': 4.6500000000000005e-05, 'epoch': 0.12}
# {'loss': 3.2934, 'learning_rate': 4.600000000000001e-05, 'epoch': 0.14}
# {'loss': 3.2612, 'learning_rate': 4.55e-05, 'epoch': 0.16}
# {'loss': 3.2721, 'learning_rate': 4.5e-05, 'epoch': 0.17}
#  10%|███▎                             | 5000/50000 [1:07:05<10:20:39,  1.21it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:04<00:04,  2.45s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:08<00:02,  2.86s/it]
# 100%|█████████████████████████████████████████████| 4/4 [00:12<00:00,  3.39s/it]Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.701 seconds.
# Prefix dict has been built successfully.
#
# {'eval_rouge-1': 32.621345999999996, 'eval_rouge-2': 7.534670000000001, 'eval_rouge-l': 25.543644000000004, 'eval_bleu-4': 0.039768692629516975, 'eval_runtime': 17.6265, 'eval_samples_per_second': 2.837, 'eval_steps_per_second': 0.227, 'epoch': 0.17}
#  10%|███▎                             | 5000/50000 [1:07:22<10:20:39,  1.21it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:13<00:00,  3.39s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-5000
# tokenizer config file saved in ./output/tmp-checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-5000/special_tokens_map.json
# {'loss': 3.2442, 'learning_rate': 4.4500000000000004e-05, 'epoch': 0.19}
# {'loss': 3.2189, 'learning_rate': 4.4000000000000006e-05, 'epoch': 0.21}
# {'loss': 3.2069, 'learning_rate': 4.35e-05, 'epoch': 0.23}
# {'loss': 3.2204, 'learning_rate': 4.3e-05, 'epoch': 0.24}
# {'loss': 3.2184, 'learning_rate': 4.25e-05, 'epoch': 0.26}
# {'loss': 3.2231, 'learning_rate': 4.2e-05, 'epoch': 0.28}
# {'loss': 3.1965, 'learning_rate': 4.15e-05, 'epoch': 0.3}
# {'loss': 3.1709, 'learning_rate': 4.1e-05, 'epoch': 0.31}
# {'loss': 3.1512, 'learning_rate': 4.05e-05, 'epoch': 0.33}
# {'loss': 3.1599, 'learning_rate': 4e-05, 'epoch': 0.35}
#  20%|██████▌                          | 10000/50000 [2:14:52<8:37:58,  1.29it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:05<00:05,  2.85s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:08<00:02,  2.94s/it]
#
# {'eval_rouge-1': 33.064727999999995, 'eval_rouge-2': 8.266416, 'eval_rouge-l': 25.634614000000003, 'eval_bleu-4': 0.04132012743071245, 'eval_runtime': 23.2231, 'eval_samples_per_second': 2.153, 'eval_steps_per_second': 0.172, 'epoch': 0.35}
#  20%|██████▌                          | 10000/50000 [2:15:15<8:37:58,  1.29it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:12<00:00,  2.99s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-10000
# tokenizer config file saved in ./output/tmp-checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-10000/special_tokens_map.json
# {'loss': 3.1652, 'learning_rate': 3.9500000000000005e-05, 'epoch': 0.37}
# {'loss': 3.1713, 'learning_rate': 3.9000000000000006e-05, 'epoch': 0.38}
# {'loss': 3.1485, 'learning_rate': 3.85e-05, 'epoch': 0.4}
# {'loss': 3.1508, 'learning_rate': 3.8e-05, 'epoch': 0.42}
# {'loss': 3.1417, 'learning_rate': 3.7500000000000003e-05, 'epoch': 0.44}
# {'loss': 3.1706, 'learning_rate': 3.7e-05, 'epoch': 0.45}
# {'loss': 3.1412, 'learning_rate': 3.65e-05, 'epoch': 0.47}
# {'loss': 3.1415, 'learning_rate': 3.6e-05, 'epoch': 0.49}
# {'loss': 3.1395, 'learning_rate': 3.55e-05, 'epoch': 0.51}
# {'loss': 3.1274, 'learning_rate': 3.5e-05, 'epoch': 0.52}
#  30%|█████████▉                       | 15000/50000 [3:23:01<7:41:35,  1.26it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:04<00:04,  2.23s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:07<00:02,  2.74s/it]
#
# {'eval_rouge-1': 33.472296, 'eval_rouge-2': 8.429166, 'eval_rouge-l': 26.263222, 'eval_bleu-4': 0.04007041986030932, 'eval_runtime': 15.1981, 'eval_samples_per_second': 3.29, 'eval_steps_per_second': 0.263, 'epoch': 0.52}
#  30%|█████████▉                       | 15000/50000 [3:23:16<7:41:35,  1.26it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:11<00:00,  2.93s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-15000
# tokenizer config file saved in ./output/tmp-checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-15000/special_tokens_map.json
# {'loss': 3.1215, 'learning_rate': 3.45e-05, 'epoch': 0.54}
# {'loss': 3.1252, 'learning_rate': 3.4000000000000007e-05, 'epoch': 0.56}
# {'loss': 3.1175, 'learning_rate': 3.35e-05, 'epoch': 0.58}
# {'loss': 3.1241, 'learning_rate': 3.3e-05, 'epoch': 0.59}
# {'loss': 3.0999, 'learning_rate': 3.2500000000000004e-05, 'epoch': 0.61}
# {'loss': 3.1275, 'learning_rate': 3.2000000000000005e-05, 'epoch': 0.63}
# {'loss': 3.1141, 'learning_rate': 3.15e-05, 'epoch': 0.65}
# {'loss': 3.1373, 'learning_rate': 3.1e-05, 'epoch': 0.66}
# {'loss': 3.1257, 'learning_rate': 3.05e-05, 'epoch': 0.68}
# {'loss': 3.1018, 'learning_rate': 3e-05, 'epoch': 0.7}
#  40%|█████████████▏                   | 20000/50000 [4:31:10<7:09:55,  1.16it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:03<00:03,  1.94s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:07<00:02,  2.52s/it]
#
# {'eval_rouge-1': 33.977481999999995, 'eval_rouge-2': 8.086088, 'eval_rouge-l': 26.110940000000006, 'eval_bleu-4': 0.03770756321012976, 'eval_runtime': 18.3991, 'eval_samples_per_second': 2.718, 'eval_steps_per_second': 0.217, 'epoch': 0.7}
#  40%|█████████████▏                   | 20000/50000 [4:31:29<7:09:55,  1.16it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:10<00:00,  2.71s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-20000
# tokenizer config file saved in ./output/tmp-checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-20000/special_tokens_map.json
# {'loss': 3.1062, 'learning_rate': 2.95e-05, 'epoch': 0.72}
# {'loss': 3.128, 'learning_rate': 2.9e-05, 'epoch': 0.73}
# {'loss': 3.1034, 'learning_rate': 2.8499999999999998e-05, 'epoch': 0.75}
# {'loss': 3.1051, 'learning_rate': 2.8000000000000003e-05, 'epoch': 0.77}
# {'loss': 3.1133, 'learning_rate': 2.7500000000000004e-05, 'epoch': 0.79}
# {'loss': 3.118, 'learning_rate': 2.7000000000000002e-05, 'epoch': 0.8}
# {'loss': 3.096, 'learning_rate': 2.6500000000000004e-05, 'epoch': 0.82}
# {'loss': 3.0809, 'learning_rate': 2.6000000000000002e-05, 'epoch': 0.84}
# {'loss': 3.1022, 'learning_rate': 2.5500000000000003e-05, 'epoch': 0.86}
# {'loss': 3.0772, 'learning_rate': 2.5e-05, 'epoch': 0.87}
#  50%|████████████████▌                | 25000/50000 [5:39:29<5:21:33,  1.30it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:06<00:06,  3.28s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:10<00:03,  3.36s/it]
#
# {'eval_rouge-1': 32.432768, 'eval_rouge-2': 7.931297999999999, 'eval_rouge-l': 25.226699999999997, 'eval_bleu-4': 0.039773289719839414, 'eval_runtime': 23.8734, 'eval_samples_per_second': 2.094, 'eval_steps_per_second': 0.168, 'epoch': 0.87}
#  50%|████████████████▌                | 25000/50000 [5:39:53<5:21:33,  1.30it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:12<00:00,  2.97s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-25000
# tokenizer config file saved in ./output/tmp-checkpoint-25000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-25000/special_tokens_map.json
# {'loss': 3.0818, 'learning_rate': 2.45e-05, 'epoch': 0.89}
# {'loss': 3.0874, 'learning_rate': 2.4e-05, 'epoch': 0.91}
# {'loss': 3.0946, 'learning_rate': 2.35e-05, 'epoch': 0.92}
# {'loss': 3.0683, 'learning_rate': 2.3000000000000003e-05, 'epoch': 0.94}
# {'loss': 3.0921, 'learning_rate': 2.25e-05, 'epoch': 0.96}
# {'loss': 3.0765, 'learning_rate': 2.2000000000000003e-05, 'epoch': 0.98}
# {'loss': 3.0964, 'learning_rate': 2.15e-05, 'epoch': 0.99}
# {'loss': 3.0533, 'learning_rate': 2.1e-05, 'epoch': 1.01}
# {'loss': 3.0553, 'learning_rate': 2.05e-05, 'epoch': 1.03}
# {'loss': 3.0678, 'learning_rate': 2e-05, 'epoch': 1.05}
#  60%|███████████████████▊             | 30000/50000 [6:47:51<5:05:19,  1.09it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:10<00:10,  5.41s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:14<00:04,  4.62s/it]
#
# {'eval_rouge-1': 34.564916, 'eval_rouge-2': 8.622301999999998, 'eval_rouge-l': 26.288464000000005, 'eval_bleu-4': 0.03967877615155305, 'eval_runtime': 21.4443, 'eval_samples_per_second': 2.332, 'eval_steps_per_second': 0.187, 'epoch': 1.05}
#  60%|███████████████████▊             | 30000/50000 [6:48:12<5:05:19,  1.09it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:16<00:00,  3.76s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-30000
# tokenizer config file saved in ./output/tmp-checkpoint-30000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-30000/special_tokens_map.json
# {'loss': 3.0548, 'learning_rate': 1.9500000000000003e-05, 'epoch': 1.06}
# {'loss': 3.0381, 'learning_rate': 1.9e-05, 'epoch': 1.08}
# {'loss': 3.0642, 'learning_rate': 1.85e-05, 'epoch': 1.1}
# {'loss': 3.0657, 'learning_rate': 1.8e-05, 'epoch': 1.12}
# {'loss': 3.026, 'learning_rate': 1.75e-05, 'epoch': 1.13}
# {'loss': 3.0421, 'learning_rate': 1.7000000000000003e-05, 'epoch': 1.15}
# {'loss': 3.0601, 'learning_rate': 1.65e-05, 'epoch': 1.17}
# {'loss': 3.057, 'learning_rate': 1.6000000000000003e-05, 'epoch': 1.19}
# {'loss': 3.0551, 'learning_rate': 1.55e-05, 'epoch': 1.2}
# {'loss': 3.052, 'learning_rate': 1.5e-05, 'epoch': 1.22}
#  70%|███████████████████████          | 35000/50000 [7:56:10<3:16:32,  1.27it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:04<00:04,  2.08s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:07<00:02,  2.67s/it]
#
# {'eval_rouge-1': 34.08027200000001, 'eval_rouge-2': 7.77516, 'eval_rouge-l': 26.315232000000005, 'eval_bleu-4': 0.038490624103663704, 'eval_runtime': 21.3209, 'eval_samples_per_second': 2.345, 'eval_steps_per_second': 0.188, 'epoch': 1.22}
#  70%|███████████████████████          | 35000/50000 [7:56:31<3:16:32,  1.27it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.47s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-35000
# tokenizer config file saved in ./output/tmp-checkpoint-35000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-35000/special_tokens_map.json
# {'loss': 3.052, 'learning_rate': 1.45e-05, 'epoch': 1.24}
# {'loss': 3.0797, 'learning_rate': 1.4000000000000001e-05, 'epoch': 1.26}
# {'loss': 3.036, 'learning_rate': 1.3500000000000001e-05, 'epoch': 1.27}
# {'loss': 3.0318, 'learning_rate': 1.3000000000000001e-05, 'epoch': 1.29}
# {'loss': 3.0547, 'learning_rate': 1.25e-05, 'epoch': 1.31}
# {'loss': 3.0585, 'learning_rate': 1.2e-05, 'epoch': 1.33}
# {'loss': 3.0453, 'learning_rate': 1.1500000000000002e-05, 'epoch': 1.34}
# {'loss': 3.0513, 'learning_rate': 1.1000000000000001e-05, 'epoch': 1.36}
# {'loss': 3.0227, 'learning_rate': 1.05e-05, 'epoch': 1.38}
# {'loss': 3.0358, 'learning_rate': 1e-05, 'epoch': 1.4}
#  80%|██████████████████████████▍      | 40000/50000 [9:04:01<2:10:51,  1.27it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:10<00:10,  5.39s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:14<00:04,  4.49s/it]
#
# {'eval_rouge-1': 33.456219999999995, 'eval_rouge-2': 7.780761999999999, 'eval_rouge-l': 26.295364, 'eval_bleu-4': 0.03800658282047404, 'eval_runtime': 20.3115, 'eval_samples_per_second': 2.462, 'eval_steps_per_second': 0.197, 'epoch': 1.4}
#  80%|██████████████████████████▍      | 40000/50000 [9:04:22<2:10:51,  1.27it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:16<00:00,  3.68s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-40000
# tokenizer config file saved in ./output/tmp-checkpoint-40000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-40000/special_tokens_map.json
# {'loss': 3.0358, 'learning_rate': 9.5e-06, 'epoch': 1.41}
# {'loss': 3.0474, 'learning_rate': 9e-06, 'epoch': 1.43}
# {'loss': 3.0402, 'learning_rate': 8.500000000000002e-06, 'epoch': 1.45}
# {'loss': 3.0349, 'learning_rate': 8.000000000000001e-06, 'epoch': 1.47}
# {'loss': 3.0199, 'learning_rate': 7.5e-06, 'epoch': 1.48}
# {'loss': 3.0378, 'learning_rate': 7.000000000000001e-06, 'epoch': 1.5}
# {'loss': 3.0293, 'learning_rate': 6.5000000000000004e-06, 'epoch': 1.52}
# {'loss': 3.0651, 'learning_rate': 6e-06, 'epoch': 1.54}
# {'loss': 3.0205, 'learning_rate': 5.500000000000001e-06, 'epoch': 1.55}
# {'loss': 3.031, 'learning_rate': 5e-06, 'epoch': 1.57}
#  90%|████████████████████████████▊   | 45000/50000 [10:12:11<1:08:51,  1.21it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:05<00:05,  2.69s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:09<00:03,  3.08s/it]
#
# {'eval_rouge-1': 33.772318000000006, 'eval_rouge-2': 7.5391439999999985, 'eval_rouge-l': 26.131618, 'eval_bleu-4': 0.035913603621368806, 'eval_runtime': 16.4258, 'eval_samples_per_second': 3.044, 'eval_steps_per_second': 0.244, 'epoch': 1.57}
#  90%|████████████████████████████▊   | 45000/50000 [10:12:27<1:08:51,  1.21it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:12<00:00,  3.24s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-45000
# tokenizer config file saved in ./output/tmp-checkpoint-45000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-45000/special_tokens_map.json
# {'loss': 3.0248, 'learning_rate': 4.5e-06, 'epoch': 1.59}
# {'loss': 3.0166, 'learning_rate': 4.000000000000001e-06, 'epoch': 1.61}
# {'loss': 3.0327, 'learning_rate': 3.5000000000000004e-06, 'epoch': 1.62}
# {'loss': 3.041, 'learning_rate': 3e-06, 'epoch': 1.64}
# {'loss': 3.0396, 'learning_rate': 2.5e-06, 'epoch': 1.66}
# {'loss': 3.0268, 'learning_rate': 2.0000000000000003e-06, 'epoch': 1.68}
# {'loss': 3.0198, 'learning_rate': 1.5e-06, 'epoch': 1.69}
# {'loss': 3.0221, 'learning_rate': 1.0000000000000002e-06, 'epoch': 1.71}
# {'loss': 3.0357, 'learning_rate': 5.000000000000001e-07, 'epoch': 1.73}
# {'loss': 3.0288, 'learning_rate': 0.0, 'epoch': 1.75}
# 100%|██████████████████████████████████| 50000/50000 [11:20:15<00:00,  1.22it/s]***** Running Evaluation *****
#   Num examples = 50
#   Batch size = 16
#
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
#  50%|██████████████████████▌                      | 2/4 [00:04<00:04,  2.05s/it]
#  75%|█████████████████████████████████▊           | 3/4 [00:07<00:02,  2.56s/it]
#
# {'eval_rouge-1': 33.780925999999994, 'eval_rouge-2': 7.699952000000001, 'eval_rouge-l': 25.841308000000005, 'eval_bleu-4': 0.03884295294631726, 'eval_runtime': 13.7602, 'eval_samples_per_second': 3.634, 'eval_steps_per_second': 0.291, 'epoch': 1.75}
# 100%|██████████████████████████████████| 50000/50000 [11:20:28<00:00,  1.22it/s]
# 100%|█████████████████████████████████████████████| 4/4 [00:09<00:00,  2.41s/it]
#                                                                                 Saving model checkpoint to ./output/tmp-checkpoint-50000
# tokenizer config file saved in ./output/tmp-checkpoint-50000/tokenizer_config.json
# Special tokens file saved in ./output/tmp-checkpoint-50000/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 40828.9929, 'train_samples_per_second': 4.898, 'train_steps_per_second': 1.225, 'train_loss': 3.117409453125, 'epoch': 1.75}
# 100%|██████████████████████████████████| 50000/50000 [11:20:28<00:00,  1.22it/s]
# ***** Running Prediction *****
#   Num examples = 1070
#   Batch size = 16
# 100%|███████████████████████████████████████████| 67/67 [05:18<00:00,  4.75s/it]

# %% [markdown]
# ## 3. 使用微调的数据集进行推理
# 在完成微调任务之后，我们可以查看到 `output` 文件夹下多了很多个`checkpoint-*`的文件夹，这些文件夹代表了训练的轮数。
# 我们选择最后一轮的微调权重，并使用inference进行导入。

# %%
# !ls output/
# Out:
# checkpoint-10000  checkpoint-25000  checkpoint-40000  checkpoint-50000
# checkpoint-15000  checkpoint-30000  checkpoint-45000
# checkpoint-20000  checkpoint-35000  checkpoint-5000

# %%
# !export python_dir='/home/yuxiang/miniconda3/envs/py311_llm_dev/bin' \
&& export CUDA_VISIBLE_DEVICES=0 \
&& ${python_dir}/python3  inference_hf.py output/checkpoint-50000/ --prompt "类型#裙*版型#显瘦*材质#网纱*风格#性感*裙型#百褶*裙下摆#压褶*裙长#连衣裙*裙衣门襟#拉链*裙衣门襟#套头*裙款式#拼接*裙款式#拉链*裙款式#木耳边*裙款式#抽褶*裙款式#不规则"
# Out:
# Loading checkpoint shards: 100%|██████████████████| 7/7 [00:03<00:00,  2.32it/s]
# 这款套头连衣裙，选用网纱面料，轻盈飘逸，带来仙气。采用不规则的百褶裙摆，立体感十足，行走间摇曳生姿。不规则的压褶设计，增加层次感，增添灵动感。木耳边拼接，甜美减龄，衬托小女生的可爱甜美。后背拉链设计，方便穿脱，又增加穿脱的舒适度。

# %% [markdown]
# ## 4. 总结
# 到此位置，我们就完成了使用单张 GPU Lora 来微调 ChatGLM3-6B 模型，使其能生产出更好的广告。
# 在本章节中，你将会学会：
# + 如何使用模型进行 Lora 微调
# + 微调数据集的准备和对齐
# + 使用微调的模型进行推理
